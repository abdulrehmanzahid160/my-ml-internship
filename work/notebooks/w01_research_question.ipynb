# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdulrehmanzahid160/my-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#I'm choosing Lane 2: Refresh / Content Opportunity Scoring. My Week 1 pipeline run already demonstrated this exact problem — ranking pages for review — and showed a learned model clearly beating a hand-written rule, so I have real evidence this lane is worth pursuing.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Question: Which content pages should a reviewer check first for refresh, out of a large inventory, given limited review time?

#Unit of analysis: one content page (content_id)

#Output: a ranked list of pages with a score and a reason code (e.g. "stale and still getting traffic")

#Action: a content reviewer manually checks/refreshes the top-ranked pages first instead of guessing

#Cost of a wrong call: if the model ranks a page highly but it isn't actually worth reviewing, the team wastes limited review time — a real but non-catastrophic opportunity cost

#Why ML can help: a simple hand-written rule leaves real signal on the table. My Week 1 run showed the hand-rule baseline scored 12 of its top 50 picks correctly, while a random forest model scored 37 of its top 50 correctly — roughly 3x better.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

subprocess.run([sys.executable, "scripts/run_all.py"], check=True)

import json
res = json.load(open("outputs/model_results.json"))
base = res["baseline"]["baseline_precision_at_50"]
rf   = res["models"]["random_forest"]["precision_at_50"]

print(f"Hand-rule Precision@50: {base:.3f}  (~{round(base*50)} of top 50 correct)")
print(f"Random forest Precision@50: {rf:.3f}  (~{round(rf*50)} of top 50 correct)")
print(f"Lift: {rf/base:.1f}x")
# Out:
# Hand-rule Precision@50: 0.240  (~12 of top 50 correct)
# Random forest Precision@50: 0.740  (~37 of top 50 correct)
# Lift: 3.1x

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#I can claim the model ranks pages better than the hand rule against this proxy label (trend_direction == "down"), on this 30,000-row anonymized starter sample. I cannot claim that refreshing a flagged page will cause it to recover — that would require a real experiment. I also cannot generalize this result to the full ~79M-row warehouse without re-testing there. This is observed/directional evidence, not proof of a causal effect or of any Google algorithm behavior.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
